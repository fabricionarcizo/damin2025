# %% [markdown]
# # Multiclass Classification Confusion Matrix
#
# This notebook demonstrates how to create and visualize a confusion matrix for multiclass classification using scikit-learn. Unlike binary classification, multiclass problems involve more than two classes, making the confusion matrix a square matrix that shows prediction accuracy across all class combinations.
#
# **License:** MIT License
# **Copyright:** (c) 2024 Fabricio Batista Narcizo

# %% [markdown]
# ## Import Required Libraries
#
# Import libraries for data generation, modeling, evaluation, and visualization.

# %%
# Import the required libraries.
import matplotlib.pyplot as plt

from matplotlib.colors import LinearSegmentedColormap
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import ConfusionMatrixDisplay

from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Step 1: Generate Multiclass Dataset
#
# Create a synthetic dataset with 5 features and 3 classes for multiclass classification using scikit-learn's make_classification function.

# %%
# Step 1: Generate a dataset for multiclass classification (adjusting
# parameters).
X, y = make_classification(
    n_samples=1000, n_features=5, n_informative=3,
    n_redundant=1, n_classes=3, random_state=42
)

# %% [markdown]
# ## Step 2: Split Data into Training and Testing Sets
#
# Divide the dataset into training and testing subsets for model evaluation.

# %%
# Step 2: Split the data into training and testing sets.
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %% [markdown]
# ## Step 3: Train Decision Tree Classifier
#
# Initialize and train a Decision Tree classifier for multiclass classification.

# %%
# Step 3: Train a Decision Tree Classifier for multiclass classification.
classifier = DecisionTreeClassifier(random_state=42)
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %% [markdown]
# ## Step 4: Make Predictions
#
# Use the trained model to predict classes for the test dataset.

# %%
# Step 4: Make predictions on the test set.
y_pred = classifier.predict(X_test)

# %% [markdown]
# ## Step 5: Compute Confusion Matrix
#
# Calculate the confusion matrix to evaluate multiclass classification performance.

# %%
# Step 5: Compute the confusion matrix.
cm = confusion_matrix(y_test, y_pred)

# %% [markdown]
# ## Step 6: Visualize Confusion Matrix
#
# Display the confusion matrix using scikit-learn's ConfusionMatrixDisplay for clear visualization of multiclass prediction results.

# %%
# Step 6: Display the confusion matrix.
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm, display_labels=classifier.classes_
)
cmap = LinearSegmentedColormap.from_list(
    "custom_yellow", ["#FFFFFF", "#F59B11"])
disp.plot(cmap=cmap)
plt.title("Confusion Matrix for Multiclass Classification")
plt.show()

# %% [markdown]
# ## Understanding Multiclass Confusion Matrix
#
# In a multiclass confusion matrix:
# - **Rows** represent the actual (true) classes
# - **Columns** represent the predicted classes
# - **Diagonal elements** show correct predictions for each class
# - **Off-diagonal elements** show misclassifications
#
# The matrix provides insights into which classes are most commonly confused with each other, helping identify areas where the model needs improvement. For multiclass problems, metrics like precision, recall, and F1-score are calculated for each class individually.
