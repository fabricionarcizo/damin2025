# %% [markdown]
# # Feature Analysis with Clustering
#
# This notebook demonstrates how to use heatmaps to analyze the average feature values across clusters.

# %% [markdown]
# ## Import Required Libraries
#
# Import the necessary libraries including matplotlib, pandas, seaborn, and scikit-learn.

# %%
# Import the required libraries.
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.cluster import KMeans

from sklearn.datasets import load_iris

# %% [markdown]
# ## Load Iris Dataset
#
# Load the Iris dataset which contains measurements of sepal and petal dimensions.

# %%
# Load the Iris dataset.
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# %% [markdown]
# ## Perform K-Means Clustering
#
# Apply K-Means clustering with 3 clusters to the Iris dataset.

# %%
# Perform k-Means clustering.
kmeans = KMeans(n_clusters=3, random_state=42)
df["Cluster"] = kmeans.fit_predict(df)

# %% [markdown]
# ## Calculate Average Feature Values
#
# Calculate the mean value of each feature for each cluster.

# %%
# Calculate average feature values for each cluster.
cluster_averages = df.groupby("Cluster").mean()

# %% [markdown]
# ## Visualize with Heatmap
#
# Create a heatmap to visualize the average feature values across clusters.

# %%
# Plot the heatmap for average feature values across clusters.
plt.figure(figsize=(12, 8))
sns.heatmap(
    cluster_averages, annot=True, cmap="Reds", fmt=".2f", linewidths=.5,
    linecolor="black", cbar_kws={"shrink": 0.8}
)
plt.title("Heatmap of Average Feature Values Across Clusters")
plt.xlabel("Features")
plt.ylabel("Clusters")
plt.tight_layout()
plt.show()
